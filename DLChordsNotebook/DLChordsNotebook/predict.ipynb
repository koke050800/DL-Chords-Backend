# %%
import librosa
import madmom
from madmom.features.beats import RNNBeatProcessor, MultiModelSelectionProcessor
from scipy import signal
import numpy as np
import numpy as np2

# %%
def peak_picking(beat_times, total_samples, kernel_size, offset):

    # smoothing the beat function
    cut_off_norm = len(beat_times)/total_samples*100/2
    b, a = signal.butter(1, cut_off_norm)
    beat_times = signal.filtfilt(b, a, beat_times)

    # creating a list of samples for the rnn beats
    beat_samples = np2.linspace(0, total_samples, len(beat_times), endpoint=True, dtype=int)

    n_t_medians = signal.medfilt(beat_times, kernel_size=kernel_size)
    offset = 0.01
    peaks = []

    for i in range(len(beat_times)-1):
        if beat_times[i] > 0:
            if beat_times[i] > beat_times[i-1]:
                if beat_times[i] > beat_times[i+1]:
                    if beat_times[i] > (n_t_medians[i] + offset):
                        peaks.append(int(beat_samples[i]))
    return peaks

# %%
def analyze(data_audio, sample_rate):

    data_result = {}

    # sample rate
    data_result['sample_rate'] = sample_rate

    # getting duration in seconds
    data_result['duration'] = librosa.get_duration(y=data_audio, sr=sample_rate)


    rnn_processor = RNNBeatProcessor(post_processor=None)
    predictions = rnn_processor(data_audio)
    mm_processor = MultiModelSelectionProcessor(num_ref_predictions=None)
    beats = mm_processor(predictions)

    data_result['beat_samples'] = peak_picking(beats, len(data_audio), 5, 0.01)

    if len(data_result['beat_samples']) < 3:
        data_result['beat_samples'] = peak_picking(beats, len(data_audio), 25, 0.01)

    if data_result['beat_samples'] == []:
        data_result['beat_samples'] = [0]

    data_result['number_of_beats'] = len(data_result['beat_samples'])

    return data_result

# %%
def preprocessing_audio_in(rate, data, fft_size = 16384):
    """
    Convert the input audio sampled at the input rate
    to a list of HPCP vectors computed using the input fft_size
    (effectively outputing int(len(data)/fft_size)) HPCP vectors
    """
    output_samples = []
    for i in range(int(len(data)/fft_size)):
        ###Computing the DFT by taking a fragment of the audio 
        dft = np.fft.fft(data[fft_size*i:fft_size*(i+1)])
        ### Computiong the Harmonic pitch class profile
        HPCP = []
        f_ref = 130.80
        M = [round(12*np.log2(rate*l/(fft_size*f_ref))) %12 if l > 0 else -1 for l in range(int(fft_size/2))]
        M = np.array(M)
        for p in range(12):
            val = np.sum((np.absolute(dft[:int(fft_size/2)])**2)* (M == p).astype(int) )
            HPCP.append(val)
        HPCP = [x/sum(HPCP) for x in HPCP]
        output_sample = HPCP
        output_samples.append(output_sample)
     
    return output_samples

# %%
'''def analyze_file(path):
    data_audio, sample_rate = librosa.load(path, sr=44100)
    return analyze(data_audio, sample_rate)'''
# Out:
# 'def analyze_file(path):\n    data_audio, sample_rate = librosa.load(path, sr=44100)\n    return analyze(data_audio, sample_rate)'

# %%
import tensorflow as tf

# %%
new_model = tf.keras.models.load_model('DLCords1.h5')
new_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 35)                455
#
#  dense_4 (Dense)             (None, 35)                1260
#
#  dense_5 (Dense)             (None, 10)                360
#
# =================================================================
# Total params: 2,075
# Trainable params: 2,075
# Non-trainable params: 0
# _________________________________________________________________

# %%
def convert_to_wav_and_filter_audio(path):
    split_cmd = "spleeter separate -p spleeter:2stems -o separate/ "+path+""
    #print(split_cmd)
    import os;os.system(split_cmd)

#convert_to_wav_and_filter_audio("quien-de-los-dos-sera.mp3")

# %%
def predict_chords(path_of_chords):
    data_audio, sample_rate = librosa.load(path_of_chords, sr=44100)
    samples_for_beat = analyze(data_audio, sample_rate)['beat_samples']
    seconds = []
    secondFinalOfChord = int()
    data_divide_in_chords = []
    
    for i in range(len(samples_for_beat)):
        if(i== len(samples_for_beat)-1):
            data_divide_in_chords.append(data_audio[samples_for_beat[i]:len(data_audio)])
        else:
            data_divide_in_chords.append(data_audio[samples_for_beat[i]:samples_for_beat[i+1]])
            
    pitchs_of_all_data = []
          
    for i in data_divide_in_chords:
        secondFinalOfChord = secondFinalOfChord  + int(len(i))
        seconds.append(secondFinalOfChord/44100)        
        pitch_s = preprocessing_audio_in(rate=sample_rate, data=i)
        if(len(pitch_s)>0):
            pitchs_of_all_data.append(pitch_s[0])#Solo enviamos el primer pitch
        
    #a1_data, a1_rate = librosa.load(path_of_chords='C:\\Users\\UPIIZ 35\\Documents\\DLChordsNotebook\\data\\Guitar_Only\\a\\a1.wav', sr=44100)
    #pitch_clean = preprocessing_audio_in(a1_rate, a1_data)
    #print(pitchs_of_all_data)

    prediction = new_model.predict(pitchs_of_all_data)
    prediction = np.argmax(prediction, axis=1).astype(int)
    
    labels_dict_reverse = {
    0:'a',
    1:'am',
    2:'bm',
    3:'c',
    4:'d',
    5:'dm',
    6:'e',
    7:'em',
    8:'f',
    9:'g'
    }

    prediction_in_string = []
    for i in prediction:   
        prediction_in_string.append(labels_dict_reverse[i])   
    
    #print(">>> ", seconds)
    #print(prediction, prediction_in_string)


    class Chord:
        def __init__(self, chord_result, time_init, time_final):
            self.chord_result = chord_result
            self.time_init = time_init
            self.time_final = time_final
    
    chords_objects = []

    for i in range(len(prediction_in_string)):
        if(i==0):
            chords_objects.append(Chord(str(prediction_in_string[i]), 0.00, round(seconds[0], 2)))
        else:
            chords_objects.append(Chord(str(prediction_in_string[i]), round(seconds[i-1], 2), round(seconds[i],2)))
           
    return chords_objects

# %%
def predict_song(path):
    print("Convirtiendo y filtrando audio...")
    convert_to_wav_and_filter_audio(path)#convertimos audio y filtramos

    path_whitout_extension = path.rsplit('.', 1)[0]
    #print(path_whitout_extension)
    path_of_chords = "separate\\" + path_whitout_extension + "\\accompaniment.wav"#ruta de archivo con extension .wav, solo con la melodia, sin voz.
    #print(path_of_chords)

    print("Prediccion de acordes en curso...")
    return predict_chords(path_of_chords)#Predecir acordes

# %%
chords_objects = predict_song("amarte-a-la-antigua.wav")
for chord_object in chords_objects:
    if(len(chord_object.chord_result)==2):
        print("CHORDISTO>>", chord_object.chord_result,"    TIEMPOS>> ", chord_object.time_init, "   -   ", chord_object.time_final)
    else:
        print("CHORDISTO>>", chord_object.chord_result,"     TIEMPOS>> ", chord_object.time_init, "   -   ", chord_object.time_final)
# Out:
# Convirtiendo y filtrando audio...
# Prediccion de acordes en curso...
# C:\Users\Omar\AppData\Local\Temp\ipykernel_13284\678056391.py:19: RuntimeWarning: invalid value encountered in double_scalars
#   HPCP = [x/sum(HPCP) for x in HPCP]
# 8/8 [==============================] - 0s 2ms/step
# CHORDISTO>> am     TIEMPOS>>  0.0    -    0.49
# CHORDISTO>> f      TIEMPOS>>  0.49    -    1.0
# CHORDISTO>> d      TIEMPOS>>  87.48    -    88.35
# CHORDISTO>> em     TIEMPOS>>  88.35    -    89.22
# CHORDISTO>> em     TIEMPOS>>  89.22    -    90.05
# CHORDISTO>> e      TIEMPOS>>  90.05    -    90.9
# CHORDISTO>> am     TIEMPOS>>  90.9    -    92.71
# CHORDISTO>> am     TIEMPOS>>  92.71    -    93.55
# CHORDISTO>> am     TIEMPOS>>  93.55    -    94.43
# CHORDISTO>> c      TIEMPOS>>  94.43    -    95.28
# CHORDISTO>> d      TIEMPOS>>  95.28    -    96.16
# CHORDISTO>> g      TIEMPOS>>  96.16    -    97.07
# CHORDISTO>> bm     TIEMPOS>>  97.07    -    99.57
# CHORDISTO>> d      TIEMPOS>>  99.57    -    100.45
# CHORDISTO>> d      TIEMPOS>>  100.45    -    101.3
# CHORDISTO>> em     TIEMPOS>>  101.3    -    102.18
# CHORDISTO>> em     TIEMPOS>>  102.18    -    103.04
# CHORDISTO>> c      TIEMPOS>>  103.04    -    103.92
# CHORDISTO>> em     TIEMPOS>>  103.92    -    104.79
# CHORDISTO>> g      TIEMPOS>>  104.79    -    105.63
# CHORDISTO>> g      TIEMPOS>>  105.63    -    106.49
# CHORDISTO>> d      TIEMPOS>>  106.49    -    107.38
# CHORDISTO>> d      TIEMPOS>>  107.38    -    108.24
# CHORDISTO>> c      TIEMPOS>>  108.24    -    109.1
# CHORDISTO>> c      TIEMPOS>>  109.1    -    109.93
# CHORDISTO>> c      TIEMPOS>>  109.93    -    110.79
# CHORDISTO>> c      TIEMPOS>>  110.79    -    111.67
# CHORDISTO>> am     TIEMPOS>>  111.67    -    112.54
# CHORDISTO>> am     TIEMPOS>>  112.54    -    113.4
# CHORDISTO>> g      TIEMPOS>>  113.4    -    114.26
# CHORDISTO>> g      TIEMPOS>>  114.26    -    115.1
# CHORDISTO>> d      TIEMPOS>>  115.1    -    115.95
# CHORDISTO>> d      TIEMPOS>>  115.95    -    116.79
# CHORDISTO>> d      TIEMPOS>>  116.79    -    117.67
# CHORDISTO>> d      TIEMPOS>>  117.67    -    118.5
# CHORDISTO>> am     TIEMPOS>>  118.5    -    119.34
# CHORDISTO>> c      TIEMPOS>>  119.34    -    120.19
# CHORDISTO>> g      TIEMPOS>>  120.19    -    121.05
# CHORDISTO>> bm     TIEMPOS>>  121.05    -    121.88
# CHORDISTO>> d      TIEMPOS>>  121.88    -    122.72
# CHORDISTO>> d      TIEMPOS>>  122.72    -    123.58
# CHORDISTO>> d      TIEMPOS>>  123.58    -    124.45
# CHORDISTO>> am     TIEMPOS>>  124.45    -    125.36
# CHORDISTO>> am     TIEMPOS>>  125.36    -    127.11
# CHORDISTO>> am     TIEMPOS>>  127.11    -    127.99
# CHORDISTO>> am     TIEMPOS>>  127.99    -    128.85
# CHORDISTO>> d      TIEMPOS>>  128.85    -    129.71
# CHORDISTO>> d      TIEMPOS>>  129.71    -    130.55
# CHORDISTO>> d      TIEMPOS>>  130.55    -    131.4
# CHORDISTO>> d      TIEMPOS>>  131.4    -    132.25
# CHORDISTO>> g      TIEMPOS>>  132.25    -    133.11
# CHORDISTO>> g      TIEMPOS>>  133.11    -    133.95
# CHORDISTO>> d      TIEMPOS>>  133.95    -    134.81
# CHORDISTO>> d      TIEMPOS>>  134.81    -    135.67
# CHORDISTO>> em     TIEMPOS>>  135.67    -    136.53
# CHORDISTO>> em     TIEMPOS>>  136.53    -    137.36
# CHORDISTO>> e      TIEMPOS>>  137.36    -    138.22
# CHORDISTO>> e      TIEMPOS>>  138.22    -    139.08
# CHORDISTO>> am     TIEMPOS>>  139.08    -    139.95
# CHORDISTO>> am     TIEMPOS>>  139.95    -    140.78
# CHORDISTO>> am     TIEMPOS>>  140.78    -    141.64
# CHORDISTO>> am     TIEMPOS>>  141.64    -    142.5
# CHORDISTO>> d      TIEMPOS>>  142.5    -    143.36
# CHORDISTO>> d      TIEMPOS>>  143.36    -    144.2
# CHORDISTO>> d      TIEMPOS>>  144.2    -    145.05
# CHORDISTO>> d      TIEMPOS>>  145.05    -    145.91
# CHORDISTO>> g      TIEMPOS>>  145.91    -    146.78
# CHORDISTO>> g      TIEMPOS>>  146.78    -    147.63
# CHORDISTO>> d      TIEMPOS>>  147.63    -    148.48
# CHORDISTO>> d      TIEMPOS>>  148.48    -    149.32
# CHORDISTO>> em     TIEMPOS>>  149.32    -    150.19
# CHORDISTO>> em     TIEMPOS>>  150.19    -    151.0
# CHORDISTO>> e      TIEMPOS>>  151.0    -    151.87
# CHORDISTO>> e      TIEMPOS>>  151.87    -    152.74
# CHORDISTO>> am     TIEMPOS>>  152.74    -    153.6
# CHORDISTO>> am     TIEMPOS>>  153.6    -    154.42
# CHORDISTO>> am     TIEMPOS>>  154.42    -    155.27
# CHORDISTO>> c      TIEMPOS>>  155.27    -    156.12
# CHORDISTO>> d      TIEMPOS>>  156.12    -    157.0
# CHORDISTO>> d      TIEMPOS>>  157.0    -    157.84
# CHORDISTO>> d      TIEMPOS>>  157.84    -    158.71
# CHORDISTO>> d      TIEMPOS>>  158.71    -    159.57
# CHORDISTO>> c      TIEMPOS>>  159.57    -    160.43
# CHORDISTO>> c      TIEMPOS>>  160.43    -    161.27
# CHORDISTO>> c      TIEMPOS>>  161.27    -    162.12
# CHORDISTO>> c      TIEMPOS>>  162.12    -    162.98
# CHORDISTO>> g      TIEMPOS>>  162.98    -    163.82
# CHORDISTO>> g      TIEMPOS>>  163.82    -    164.69
# CHORDISTO>> g      TIEMPOS>>  164.69    -    165.55
# CHORDISTO>> bm     TIEMPOS>>  165.55    -    166.4
# CHORDISTO>> am     TIEMPOS>>  166.4    -    167.26
# CHORDISTO>> c      TIEMPOS>>  167.26    -    168.09
# CHORDISTO>> g      TIEMPOS>>  168.09    -    168.96
# CHORDISTO>> g      TIEMPOS>>  168.96    -    169.79
# CHORDISTO>> d      TIEMPOS>>  169.79    -    170.65
# CHORDISTO>> d      TIEMPOS>>  170.65    -    171.5
# CHORDISTO>> d      TIEMPOS>>  171.5    -    172.36
# CHORDISTO>> am     TIEMPOS>>  172.36    -    173.24
# CHORDISTO>> am     TIEMPOS>>  173.24    -    175.09
# CHORDISTO>> am     TIEMPOS>>  175.09    -    175.97
# CHORDISTO>> am     TIEMPOS>>  175.97    -    176.83
# CHORDISTO>> d      TIEMPOS>>  176.83    -    177.68
# CHORDISTO>> d      TIEMPOS>>  177.68    -    178.51
# CHORDISTO>> d      TIEMPOS>>  178.51    -    179.38
# CHORDISTO>> d      TIEMPOS>>  179.38    -    180.21
# CHORDISTO>> g      TIEMPOS>>  180.21    -    181.07
# CHORDISTO>> g      TIEMPOS>>  181.07    -    181.89
# CHORDISTO>> d      TIEMPOS>>  181.89    -    182.74
# CHORDISTO>> d      TIEMPOS>>  182.74    -    183.59
# CHORDISTO>> em     TIEMPOS>>  183.59    -    184.46
# CHORDISTO>> em     TIEMPOS>>  184.46    -    185.27
# CHORDISTO>> e      TIEMPOS>>  185.27    -    186.12
# CHORDISTO>> e      TIEMPOS>>  186.12    -    186.97
# CHORDISTO>> am     TIEMPOS>>  186.97    -    187.83
# CHORDISTO>> am     TIEMPOS>>  187.83    -    188.67
# CHORDISTO>> am     TIEMPOS>>  188.67    -    189.52
# CHORDISTO>> am     TIEMPOS>>  189.52    -    190.33
# CHORDISTO>> d      TIEMPOS>>  190.33    -    191.15
# CHORDISTO>> d      TIEMPOS>>  191.15    -    191.96
# CHORDISTO>> d      TIEMPOS>>  191.96    -    192.8
# CHORDISTO>> d      TIEMPOS>>  192.8    -    193.65
# CHORDISTO>> g      TIEMPOS>>  193.65    -    194.49
# CHORDISTO>> bm     TIEMPOS>>  194.49    -    195.32
# CHORDISTO>> d      TIEMPOS>>  195.32    -    196.15
# CHORDISTO>> d      TIEMPOS>>  196.15    -    196.99
# CHORDISTO>> em     TIEMPOS>>  196.99    -    197.84
# CHORDISTO>> em     TIEMPOS>>  197.84    -    198.65
# CHORDISTO>> e      TIEMPOS>>  198.65    -    199.49
# CHORDISTO>> e      TIEMPOS>>  199.49    -    200.34
# CHORDISTO>> am     TIEMPOS>>  200.34    -    201.2
# CHORDISTO>> am     TIEMPOS>>  201.2    -    202.02
# CHORDISTO>> am     TIEMPOS>>  202.02    -    202.86
# CHORDISTO>> am     TIEMPOS>>  202.86    -    203.71
# CHORDISTO>> d      TIEMPOS>>  203.71    -    204.54
# CHORDISTO>> c      TIEMPOS>>  204.54    -    205.4
# CHORDISTO>> c      TIEMPOS>>  205.4    -    211.75
# CHORDISTO>> c      TIEMPOS>>  211.75    -    212.65
# CHORDISTO>> g      TIEMPOS>>  212.65    -    213.52
# CHORDISTO>> g      TIEMPOS>>  213.52    -    214.36
# CHORDISTO>> g      TIEMPOS>>  214.36    -    215.21
# CHORDISTO>> g      TIEMPOS>>  215.21    -    216.06
# CHORDISTO>> am     TIEMPOS>>  216.06    -    216.9
# CHORDISTO>> am     TIEMPOS>>  216.9    -    217.74
# CHORDISTO>> am     TIEMPOS>>  217.74    -    218.59
# CHORDISTO>> c      TIEMPOS>>  218.59    -    219.44
# CHORDISTO>> d      TIEMPOS>>  219.44    -    220.32
# CHORDISTO>> d      TIEMPOS>>  220.32    -    221.14
# CHORDISTO>> d      TIEMPOS>>  221.14    -    221.99
# CHORDISTO>> d      TIEMPOS>>  221.99    -    222.83
# CHORDISTO>> g      TIEMPOS>>  222.83    -    223.68
# CHORDISTO>> g      TIEMPOS>>  223.68    -    224.5
# CHORDISTO>> g      TIEMPOS>>  224.5    -    225.35
# CHORDISTO>> g      TIEMPOS>>  225.35    -    226.2
